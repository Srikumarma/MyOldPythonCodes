# %% [markdown]
# # CA2 E0120020

# %%
#1
dog=4
if(dog<2){
    Print("The dog is baby")
}
else{
    dog=7/dog
    cat("In Human Years it is : ",dog)
}
# Out:
# Error in parse(text = x, srcfile = src): <text>:6:1: unexpected 'else'
# 5: }
# 6: else
#    ^
# Traceback:

# %%
#2
sales=c(142037, 148588, 149232, 148280, 142200)
lab=c('bed','sofa','desk','chair','table')
per=round(sales/sum(sales)*100)
lab=paste(lab,per,"%")
pie(sales,labels = lab)
# Out:
# plot without title

# %%
#3

wait_time=c(10.4,

18.7,

15.9,

10.7,

11.8,

12.0,

17.5,

10.9,

11.4,

10.2,

13.9,

11.3,

12.5,

10.4,

11.4,

13.0,

12.7,

14.3,

11.4,

16.4,

10.6,

13.9,

14.2,

17.3,

11.2,

20.3,

19.9,

20.0,

11.2,

11.6)

# %%
library(ggplot2)

# %%
wait=data.frame(wait_time)
ggplot(data=wait,aes(x=wait_time))+geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
#4
Height=c(71,68,70,73,74)
Weight=c(170,160,175,180,190)
plot(Height,Weight,xlab="Height",ylab="Weight",main="Weight Height - Correlation")
# Out:
# Plot with title "Weight Height - Correlation"

# %%
#5
sales=c(42 ,72 ,38 ,44 ,75 ,98 ,95, 38, 66, 38, 31, 68)
salests=ts(sales,frequency = 12)
print(salests)
plot(salests,xlab="Time",ylab="Sales_count")
# Out:
#   Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 1  42  72  38  44  75  98  95  38  66  38  31  68
# plot without title
