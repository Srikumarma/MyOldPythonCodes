# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.2-cp38-cp38-win_amd64.whl (10.6 MB)
# Collecting numpy>=1.18.5
#   Downloading numpy-1.22.3-cp38-cp38-win_amd64.whl (14.7 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\software\python\envs\r-tutorial\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: six>=1.5 in d:\software\python\envs\r-tutorial\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.22.3 pandas-1.4.2 pytz-2022.1

# %%
import pandas as pd

# %%
df = pd.read_csv ('crop_production.csv')
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]

# %%
print(df.Crop.unique())
# Out:
# ['Arecanut' 'Other Kharif pulses' 'Rice' 'Banana' 'Cashewnut' 'Coconut '
#  'Dry ginger' 'Sugarcane' 'Sweet potato' 'Tapioca' 'Black pepper'
#  'Dry chillies' 'other oilseeds' 'Turmeric' 'Maize' 'Moong(Green Gram)'
#  'Urad' 'Arhar/Tur' 'Groundnut' 'Sunflower' 'Bajra' 'Castor seed'
#  'Cotton(lint)' 'Horse-gram' 'Jowar' 'Korra' 'Ragi' 'Tobacco' 'Gram'
#  'Wheat' 'Masoor' 'Sesamum' 'Linseed' 'Safflower' 'Onion'
#  'other misc. pulses' 'Samai' 'Small millets' 'Coriander' 'Potato'
#  'Other  Rabi pulses' 'Soyabean' 'Beans & Mutter(Vegetable)' 'Bhindi'
#  'Brinjal' 'Citrus Fruit' 'Cucumber' 'Grapes' 'Mango' 'Orange'
#  'other fibres' 'Other Fresh Fruits' 'Other Vegetables' 'Papaya'
#  'Pome Fruit' 'Tomato' 'Rapeseed &Mustard' 'Mesta' 'Cowpea(Lobia)' 'Lemon'
#  'Pome Granet' 'Sapota' 'Cabbage' 'Peas  (vegetable)' 'Niger seed'
#  'Bottle Gourd' 'Sannhamp' 'Varagu' 'Garlic' 'Ginger' 'Oilseeds total'
#  'Pulses total' 'Jute' 'Peas & beans (Pulses)' 'Blackgram' 'Paddy'
#  'Pineapple' 'Barley' 'Khesari' 'Guar seed' 'Moth'
#  'Other Cereals & Millets' 'Cond-spcs other' 'Turnip' 'Carrot' 'Redish'
#  'Arcanut (Processed)' 'Atcanut (Raw)' 'Cashewnut Processed'
#  'Cashewnut Raw' 'Cardamom' 'Rubber' 'Bitter Gourd' 'Drum Stick'
#  'Jack Fruit' 'Snak Guard' 'Pump Kin' 'Tea' 'Coffee' 'Cauliflower'
#  'Other Citrus Fruit' 'Water Melon' 'Total foodgrain' 'Kapas' 'Colocosia'
#  'Lentil' 'Bean' 'Jobster' 'Perilla' 'Rajmash Kholar' 'Ricebean (nagadal)'
#  'Ash Gourd' 'Beet Root' 'Lab-Lab' 'Ribed Guard' 'Yam' 'Apple' 'Peach'
#  'Pear' 'Plums' 'Litchi' 'Ber' 'Other Dry Fruit' 'Jute & mesta']

# %%
TN=df[["State_Name"] == "Tamil Nadu", "crop"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Software\Python\envs\R-Tutorial\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# D:\Software\Python\envs\R-Tutorial\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Software\Python\envs\R-Tutorial\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (False, 'crop')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21328/1409828474.py in <module>
# ----> 1 TN=df[["State_Name"] == "Tamil Nadu", "crop"].unique()
#
# D:\Software\Python\envs\R-Tutorial\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# D:\Software\Python\envs\R-Tutorial\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: (False, 'crop')

# %%
df.Crop.unique(df.State_Name='Tamil Nadu')
# Out:
#   File "C:\Users\sriku\AppData\Local\Temp/ipykernel_21328/3608539371.py", line 1
#     df.Crop.unique(df.State_Name='Tamil Nadu')
#                    ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
df.set_index('State_Name')
# Out:
#                             District_Name  Crop_Year       Season  \
# State_Name
# Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                                   ...        ...          ...
# West Bengal                       PURULIA       2014  Summer
# West Bengal                       PURULIA       2014  Summer
# West Bengal                       PURULIA       2014  Whole Year
# West Bengal                       PURULIA       2014  Winter
# West Bengal                       PURULIA       2014  Winter
#
#                                             Crop      Area  Production
# State_Name
# Andaman and Nicobar Islands             Arecanut    1254.0      2000.0
# Andaman and Nicobar Islands  Other Kharif pulses       2.0         1.0
# Andaman and Nicobar Islands                 Rice     102.0       321.0
# Andaman and Nicobar Islands               Banana     176.0       641.0
# Andaman and Nicobar Islands            Cashewnut     720.0       165.0
# ...                                          ...       ...         ...
# West Bengal                                 Rice     306.0       801.0
# West Bengal                              Sesamum     627.0       463.0
# West Bengal                            Sugarcane     324.0     16250.0
# West Bengal                                 Rice  279151.0    597899.0
# West Bengal                              Sesamum     175.0        88.0
#
# [246091 rows x 6 columns]

# %%
print(df.State_Name.unique())
# Out:
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh' 'Dadra and Nagar Haveli'
#  'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir '
#  'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab'
#  'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana ' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal']

# %%
df.set_index('States',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21328/1535467507.py in <module>
# ----> 1 df.set_index('States',inplace=True)
#
# D:\Software\Python\envs\R-Tutorial\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Software\Python\envs\R-Tutorial\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5492
#    5493         if missing:
# -> 5494             raise KeyError(f"None of {missing} are in the columns")
#    5495
#    5496         if inplace:
#
# KeyError: "None of ['States'] are in the columns"

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: numpy>=1.15 in d:\software\python\envs\r-tutorial\lib\site-packages (from seaborn) (1.22.3)
# Collecting matplotlib>=2.2
#   Downloading matplotlib-3.5.1-cp38-cp38-win_amd64.whl (7.2 MB)
# Collecting scipy>=1.0
#   Downloading scipy-1.8.0-cp38-cp38-win_amd64.whl (36.9 MB)
# Requirement already satisfied: pandas>=0.23 in d:\software\python\envs\r-tutorial\lib\site-packages (from seaborn) (1.4.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp38-cp38-win_amd64.whl (55 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\software\python\envs\r-tutorial\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\software\python\envs\r-tutorial\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in d:\software\python\envs\r-tutorial\lib\site-packages (from matplotlib>=2.2->seaborn) (21.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\software\python\envs\r-tutorial\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.31.2-py3-none-any.whl (899 kB)
# Requirement already satisfied: pytz>=2020.1 in d:\software\python\envs\r-tutorial\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in d:\software\python\envs\r-tutorial\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, scipy, matplotlib, seaborn
# Successfully installed cycler-0.11.0 fonttools-4.31.2 kiwisolver-1.4.2 matplotlib-3.5.1 scipy-1.8.0 seaborn-0.11.2
