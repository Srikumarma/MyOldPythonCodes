# %%
T=TRUE
F=FALSE

# %%
#reading a csv file
data=read.csv("input.csv")
data
# Out:
#   ID NAME SALARY.G. DEPT
# 1 1  A    10        V
# 2 2  B    20        W
# 3 3  C    30        X
# 4 4  D    40        Y
# 5 5  E    50        Z

# %%
#write in a csv file
new_data=iris
write.csv(new_data,"new_input.csv")

# %%
a=subset(data, subset = (SALARY.G. == max(SALARY.G.) | DEPT=='Y'))
a
# Out:
#   ID NAME SALARY.G. DEPT
# 4 4  D    40        Y
# 5 5  E    50        Z

# %%
install.packages("xlsx")
install.packages("readxl")
# Out:
# also installing the dependencies 'rJava', 'xlsxjars'
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# rJava  1.0-4  1.0-5              TRUE
#
#   Binaries will be installed
# package 'rJava' successfully unpacked and MD5 sums checked
# package 'xlsxjars' successfully unpacked and MD5 sums checked
# package 'xlsx' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\sriku\AppData\Local\Temp\RtmpMnJ64q\downloaded_packages
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# "downloaded length 655360 != reported length 1526096"Warning message in unzip(zipname, exdir = dest):
# "error 1 in extracting from zip file"Warning message in read.dcf(file.path(pkgname, "DESCRIPTION"), c("Package", "Type")):
# "cannot open compressed file 'readxl/DESCRIPTION', probable reason 'No such file or directory'"
# ...

# %%
install.packages("xlsx")           # Install xlsx package
library("xlsx")
# Out:
# package 'xlsx' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\sriku\AppData\Local\Temp\RtmpWY6oYH\downloaded_packages
# Warning message:
# "package 'xlsx' was built under R version 3.6.3"

# %%
a=iris
write.xlsx(a,"iris.xlsx",sheetName="Newdata")

# %%
read.xlsx("iris.xlsx",sheetName="Newdata")
# Out:
#     NA. Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   1   5.1          3.5         1.4          0.2         setosa
# 2   2   4.9          3.0         1.4          0.2         setosa
# 3   3   4.7          3.2         1.3          0.2         setosa
# 4   4   4.6          3.1         1.5          0.2         setosa
# 5   5   5.0          3.6         1.4          0.2         setosa
# 6   6   5.4          3.9         1.7          0.4         setosa
# 7   7   4.6          3.4         1.4          0.3         setosa
# 8   8   5.0          3.4         1.5          0.2         setosa
# 9   9   4.4          2.9         1.4          0.2         setosa
# 10  10  4.9          3.1         1.5          0.1         setosa
# 11  11  5.4          3.7         1.5          0.2         setosa
# 12  12  4.8          3.4         1.6          0.2         setosa
# 13  13  4.8          3.0         1.4          0.1         setosa
# ...

# %%
library(readxl)

# %%
b=read_excel("iris.xlsx", n_max=5, col_names = T)
b
# Out:
# New names:
# * `` -> ...1
#   ...1 Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 1    5.1          3.5         1.4          0.2         setosa
# 2 2    4.9          3.0         1.4          0.2         setosa
# 3 3    4.7          3.2         1.3          0.2         setosa
# 4 4    4.6          3.1         1.5          0.2         setosa
# 5 5    5.0          3.6         1.4          0.2         setosa

# %%
#txt file
datatxt=read.delim("names.txt")
datatxt
# Out:
#   Srikumar
# 1 Mr. Rushi Patel
# 2 Ms. Sneha Shah
# 3 Mr. Bhavesh Jain
# 4 Mr. Rahul Singh
# 5 Mr. Deep Darji
# 6 Ms. Kavita Ahuja

# %%
install.packages("openxlsx")
library(openxlsx)
# Out:
# also installing the dependency 'zip'
#   There are binary versions available but the source versions are later:
#          binary source needs_compilation
# zip       2.1.1  2.2.0              TRUE
# openxlsx  4.2.3  4.2.5              TRUE
#
#   Binaries will be installed
# package 'zip' successfully unpacked and MD5 sums checked
# package 'openxlsx' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\sriku\AppData\Local\Temp\RtmpioyumI\downloaded_packages
# Warning message:
# "package 'openxlsx' was built under R version 3.6.3"

# %%
Df1=iris
Df2=mtcars
Data = list("one"=Df1, "two"=Df2)
write.xlsx(Data,file= "newfile.xlsx")

# %%
df=read.xlsx("newfile.xlsx")
df
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...
