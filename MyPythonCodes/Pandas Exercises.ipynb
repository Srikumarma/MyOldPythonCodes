# %% [markdown]
# 1.Write a Pandas program to select the rows where the number of attempts in the examination is greater than 2
#
# 2.Write a Pandas program to change the score in row 'd' to 11.5.
#
# 3.Write a Pandas program to change the name 'James' to 'Suresh' in name column of the data frame.
#
# 4.Write a Pandas program to delete the 'attempts' column from the DataFrame.
#
# 5.Write a Pandas program to rename columns of a given DataFrame.

# %%
import pandas as pd
import numpy as np

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
exam_data_df=pd.DataFrame(exam_data)

# %%
exam_data_df[exam_data_df.attempts>2]
# Out:
#       name  score  attempts qualify
# 1     Dima    9.0         3      no
# 3    James    NaN         3      no
# 5  Michael   20.0         3     yes

# %%
exam_index=exam_data_df.set_index([pd.Index(labels)])

# %%
exam_index.loc['d','score']=11.5

# %%
exam_index.['name']
# Out:
#   File "<ipython-input-101-cd68b1111fe4>", line 1
#     exam_index.['name']
#                ^
# SyntaxError: invalid syntax

# %%
exam_index.name.replace('James','Suresh')
# Out:
# a    Anastasia
# b         Dima
# c    Katherine
# d       Suresh
# e        Emily
# f      Michael
# g      Matthew
# h        Laura
# i        Kevin
# j        Jonas
# Name: name, dtype: object

# %%
exam_index.drop(columns='attempts')
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# d      James   11.5      no
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# h      Laura    NaN      no
# i      Kevin    8.0      no
# j      Jonas   19.0     yes

# %%
exam_index.rename(columns={'name':'Name'})
# Out:
#         Name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# Task : Create numpy array for following values 158168416, 29029425 , 151829363, 118721995 ,88809154,97924631,108854046,118891367,111596821,82583823,92899597,125096657,146674682,80532382,137899041, and calculate Standardized and Normalized Values for the same values

# %%
array1=np.array([158168416, 29029425 , 151829363, 118721995 ,88809154,97924631,108854046,118891367,111596821,82583823,92899597,125096657,146674682,80532382,137899041])

# %%
array1
# Out:
# array([158168416,  29029425, 151829363, 118721995,  88809154,  97924631,
#        108854046, 118891367, 111596821,  82583823,  92899597, 125096657,
#        146674682,  80532382, 137899041])

# %%
array1_min=array1.min()

# %%
array1_max=array1.max()

# %%
#Normalization:X(norm)=X-Min(x)/Max(x)-Min(x)
for x in array1:
    array1_norm=(x-array1_min)/(array1_max-array1_min)
    print(array1_norm)
# Out:
# 1.0
# 0.0
# 0.9509129430940033
# 0.6945429053259368
# 0.462909989748952
# 0.5334965486914792
# 0.6181295082288509
# 0.6958544534392405
# 0.6393684460489552
# 0.41470354991390634
# 0.4945847222857735
# 0.7439057038938767
# 0.9109971828725222
# 0.39881802235856095
# 0.8430421761619618

# %%
#Standadization:X(Std)=X-Mean(x)/std(x)
def standard(array1):
    array1_mean=np.mean(array1)
    array1_std=np.std(array1)
    for y in array1:
        a_std=(y-array1_mean)/array1_std
        print(a_std)

# %%
standard(array1)
# Out:
# 1.4925611979799343
# -2.506274713456129
# 1.2962701120375288
# 0.2710883983943647
# -0.65517362268552
# -0.37290955592144354
# -0.034476238032286555
# 0.27633306408941993
# 0.05045478924350382
# -0.8479432654603825
# -0.5285115647321458
# 0.4684821299968273
# 1.1366535366315993
# -0.9114668835208047
# 0.8649126154355317

# %%
temperature=np.array([68.9,66.4,68.7,71.4,69.3,68.5,66.5,67.2,68.7,68.9,65.7,65.6,67.1,66.8])
Wind_Speed=np.array([6.9,5.8,9.2,9.2,9.2,9.2,6.9,4.7,3.4,6.9,4.7,6.9,9.2,9.2])

# %%
tmin=temperature.min()

# %%
wmin=Wind_Speed.min()

# %%
tmax=temperature.max()

# %%
wmax=Wind_Speed.max()

# %%
tmean=temperature.mean()

# %%
wmean=Wind_Speed.mean()

# %%
wstd=Wind_Speed.std()

# %%
tstd=temperature.std()

# %%
def normalization(temperature):
    tmin=temperature.min()
    tmax=temperature.max()
    for i in temperature:
        tnorm=(i-tmin)/(tmax-tmin)
        print(tnorm)
normalization(temperature)
# Out:
# 0.5689655172413801
# 0.1379310344827603
# 0.5344827586206901
# 1.0
# 0.6379310344827579
# 0.5
# 0.15517241379310412
# 0.2758620689655182
# 0.5344827586206901
# 0.5689655172413801
# 0.017241379310346264
# 0.0
# 0.25862068965517193
# 0.206896551724138

# %%
def normalization(Wind_Speed):
    wmin=Wind_Speed.min()    
    wmax=Wind_Speed.max()   
    for i in Wind_Speed:
        wnorm=(i-wmin)/(wmax-wmin)
        print(wnorm)
        
normalization(Wind_Speed)
# Out:
# 0.6034482758620692
# 0.4137931034482759
# 1.0
# 1.0
# 1.0
# 1.0
# 0.6034482758620692
# 0.22413793103448285
# 0.0
# 0.6034482758620692
# 0.22413793103448285
# 0.6034482758620692
# 1.0
# 1.0

# %%
def standard(temperature):
    tmean=temperature.mean()
    tstd=temperature.std()
    for j in temperature:
        t_std=(j-tmean)/tstd
        print(t_std)
standard(temperature)
# Out:
# 0.6782473571086176
# -0.9149511327438575
# 0.5507914779204178
# 2.2714458469610928
# 0.9331591154850082
# 0.423335598732218
# -0.8512231931497621
# -0.4051276159910673
# 0.5507914779204178
# 0.6782473571086176
# -1.3610467099025523
# -1.4247746494966569
# -0.4688555555851717
# -0.660039374367467

# %%
def standard(Wind_Speed):
    wmean=Wind_Speed.mean()
    wstd=Wind_Speed.std()
    for j in Wind_Speed:
        w_std=(j-wmean)/wstd
        print(w_std)
standard(Wind_Speed)
# Out:
# -0.1758253554049116
# -0.7399317039956674
# 1.0036697371030314
# 1.0036697371030314
# 1.0036697371030314
# 1.0036697371030314
# -0.1758253554049116
# -1.3040380525864228
# -1.9707091918300432
# -0.1758253554049116
# -1.3040380525864228
# -0.1758253554049116
# 1.0036697371030314
# 1.0036697371030314

# %% [markdown]
# 1.Write a Pandas program to display the dimensions or shape of the World alcohol consumption dataset. Also extract the column names from the dataset.
#
# 2.Write a Pandas program to select first 2 rows, 2 columns and specific two columns from World alcohol consumption dataset.
#
# 3.Write a Pandas program to select random number of rows, fraction of random rows from World alcohol consumption dataset.
#
# 4.Write a Pandas program to find and drop the missing values from World alcohol consumption dataset.
#
# 5.Write a Pandas program to remove the duplicates from 'WHO region' column of World alcohol consumption dataset.

# %%
import pandas as pd
a=pd.read_csv('world_alcohol.csv')
print(a.shape)
print(a.ndim)
print(a.columns)
# Out:
# (100, 5)
# 2
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %%
print(a[:2])
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5

# %%
print(a.iloc[:,:2].head())
# Out:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas
# 2  1985           Africa
# 3  1986         Americas
# 4  1987         Americas

# %%
a.sample(5)
# Out:
#     Year WHO region                           Country Beverage Types  \
# 41  1986     Europe                    Czech Republic           Beer
# 34  1986     Europe                Russian Federation           Wine
# 72  1987     Africa                        Mauritania          Other
# 74  1986   Americas  Bolivia (Plurinational State of)        Spirits
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
#
#     Display Value
# 41           6.82
# 34           0.80
# 72           0.00
# 74           2.06
# 64           1.26

# %%
a.sample(frac=0.5)
# Out:
#     Year             WHO region                                Country  \
# 38  1987  Eastern Mediterranean                                  Qatar
# 44  1985                 Europe                              Lithuania
# 2   1985                 Africa                           Cte d'Ivoire
# 11  1989               Americas                              Guatemala
# 0   1986        Western Pacific                               Viet Nam
# 67  1989                 Africa                                Namibia
# 93  1987                 Africa                             Madagascar
# 15  1987                 Africa                          Guinea-Bissau
# 88  1987  Eastern Mediterranean                                Lebanon
# 8   1986               Americas                    Antigua and Barbuda
# 49  1986                 Europe                                  Malta
# 10  1987                 Africa                               Botswana
# ...

# %%
a.isnull()
# Out:
#      Year  WHO region  Country  Beverage Types  Display Value
# 0   False       False    False           False          False
# 1   False       False    False           False          False
# 2   False       False    False           False          False
# 3   False       False    False           False          False
# 4   False       False    False           False          False
# ..    ...         ...      ...             ...            ...
# 95  False       False    False           False          False
# 96  False       False    False           False          False
# 97  False       False    False           False          False
# 98  False       False    False           False          False
# 99  False       False    False           False          False
#
# [100 rows x 5 columns]

# %%
a.dropna()
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
a.drop_duplicates('WHO region')
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# 1.Write a Pandas program to detect missing values of a given DataFrame. Display True or False.
#
# 2.Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.
#
# 3.Write a Pandas program to count the number of missing values in each column of a given DataFrame.
#
# 4.Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.
#
# 5.Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.

# %%
import numpy as np
b = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

# %%
b.isna
# Out:
# <bound method DataFrame.isna of      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN>

# %%
b.isna().any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %%
b.isna().count()
# Out:
# ord_no         12
# purch_amt      12
# ord_date       12
# customer_id    12
# salesman_id    12
# dtype: int64

# %%
b.replace({"?": np.nan, "--": np.nan})
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
b.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0
