# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
array=np.random.rand(5)
array
# Out:
# array([0.13069963, 0.67161277, 0.04598027, 0.0141156 , 0.36224383])

# %%
plt.plot(array,'g',linewidth=2)
plt.xlabel("range")
plt.ylabel("random number")
plt.title("First plot")
# Out:
# Text(0.5, 1.0, 'First plot')

# %%
import numpy as np
import matplotlib.pyplot as plt
temperature=np.array([68.9,66.4,68.7,71.4,69.3,68.5,66.5,67.2,68.7,68.9,65.7,65.6,67.1,66.8])
Wind_Speed=np.array([6.9,5.8,9.2,9.2,9.2,9.2,6.9,4.7,3.4,6.9,4.7,6.9,9.2,9.2])

# %%
plt.plot(temperature,'g',linewidth=2)
plt.title("Temperature")
plt.xlabel("a")
plt.ylabel("b")
plt.show()

# %%
plt.plot(Wind_Speed,'g',linewidth=2)
plt.title("Wind Speed")
plt.xlabel("a")
plt.ylabel("b")
plt.show()
