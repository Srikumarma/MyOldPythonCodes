# %%
import pandas as pd
f2=pd.read_csv('D:\C84 Bkp\Compute Report 1012.csv')
f3=pd.read_csv('D:\C84 Bkp\Compute Report 0928.csv',skiprows=1)
f4=pd.read_csv('D:\C84 Bkp\Compute Report 1012.csv',skiprows=1)
result = f2.append(f3)
f2
# Out:
#                   cluster_name       DC Name Cluster Region (Prod/Non Prod)  \
# 0        Atlanta UCS Cluster 1       Atlanta                        NonProd
# 1         SHK DATABASE CLUSTER           SHK                           Prod
# 2        SHK DATABASE CLUSTER2           SHK                           Prod
# 3              SHK DB2 Cluster           SHK                           Prod
# 4      SHK NONBILLABLE CLUSTER           SHK                           Prod
# 5          SHK GENESYS CLUSTER           SHK                           Prod
# 6          SHK GemFire Cluster           SHK                           Prod
# 7            SHK Jboss Cluster           SHK                           Prod
# 8    SHK DENSE WINDOWS CLUSTER           SHK                           prod
# 9            SHK LARGE WINDOWS           SHK                           Prod
# 10              SHK Management           SHK                           Prod
# ...
