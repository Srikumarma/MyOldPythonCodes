# %% [markdown]
# trend of the data - line chart
#
# percentage- pie chart
#
# reationship between 2 or more columns- scatter plot

# %%
x=c(11,15,23,56,87)
plot(x,type = "o",col = "blue")
# Out:
# plot without title

# %%
png(file="first_Chart.png")
x=c(11,15,23,56,87)
plot(x,type = "o",col = "blue")
dev.off()
# Out:
# png
#   2

# %%
x=c(10,20,4,55,89)
y=c(90,17,85,55,33)
plot(x,type = "o",col = "blue",xlab="month",ylab="Event count")
lines(y,type = "o")
legend("topright",legend=c("x","y"),col=c("red","blue"))
# Out:
# plot without title

# %%
plot(x,y)
# Out:
# plot without title

# %%
#scatterplot matrix
pairs(wt~disp,data=mtcars)
#top to bottom - negative corrlation
#bottom to top - positive corrlation
# Out:
# plot without title

# %%
#change the pattern of the points
plot(iris$Sepal.Width,iris$Sepal.Length,pch = 10)
# Out:
# plot without title

# %%
#3d scatter plot
install.packages("scatterplot3d")
library(scatterplot3d)
# Out:
# package 'scatterplot3d' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\sriku\AppData\Local\Temp\RtmpcZ6Y7R\downloaded_packages

# %%
attach(iris)

# %%
scatterplot3d(Sepal.Length,Sepal.Width)
# Out:
# plot without title

# %%
plot(x)
# Out:
# plot without title
