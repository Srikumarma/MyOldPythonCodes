# %%
install.packages("ggplot2")
# Out:
#   There is a binary version available but the source version is later:
#         binary source needs_compilation
# ggplot2  3.3.3  3.3.5             FALSE
# installing the source package 'ggplot2'

# %%
library(ggplot2)

# %%
ggplot((data=iris))
# Out:
# plot without title

# %%
#scatterplot
ggplot(data=iris,aes(y=Sepal.Length,x=Petal.Length))+geom_point()
# Out:
# plot without title

# %%
ggplot(data=iris,aes(y=Sepal.Length,x=Petal.Length,col=Species))+geom_point()
# Out:
# plot without title

# %%
ggplot(data=iris,aes(y=Sepal.Length,x=Petal.Length,col=Species,shape=Species))+geom_point()
# Out:
# plot without title

# %%
house=read.csv('houses.csv')
library(dplyr)

# %%
house %>% select(c(-1)) ->house
head(house)
# Out:
#   X price  lot_size waterfront age land_value construction air_cond fuel heat
# 1 1 132500 0.09     no          42 50000      0            no       3    4
# 2 2 181115 0.92     no           0 22300      0            no       2    3
# 3 3 109000 0.19     no         133  7300      0            no       2    3
# 4 4 155000 0.41     no          13 18700      0            no       2    2
# 5 5  86060 0.11     no           0 15000      1            yes      2    2
# 6 6 120000 0.68     no          31 14000      0            no       2    2
#   sewer   living_area fireplaces bathrooms rooms
# 1 Private  906        1          1.0       5
# 2 Private 1953        0          2.5       6
# 3 Public  1944        1          1.0       8
# 4 Private 1944        1          1.5       5
# 5 Public   840        0          1.0       3
# 6 Private 1152        1          1.0       8

# %% [markdown]
# # Histogram

# %%
ggplot(data=house,aes(x=price))+geom_histogram()
ggplot(data=house,aes(x=price))+geom_histogram(bins=50)
ggplot(data=house,aes(x=price))+geom_histogram(fill="palegreen")
ggplot(data=house,aes(x=price))+geom_histogram(col="green")
ggplot(data=house,aes(x=price))+geom_histogram(bins=50,fill="palegreen",col="green")
ggplot(data=house,aes(x=price,fill=air_cond))+geom_histogram()
ggplot(data=house,aes(x=price,fill=air_cond))+geom_histogram(bins=50,fill="palegreen",col="green",position="fill")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# Warning message:
# "Removed 4 rows containing missing values (geom_bar)."
# plot without title
# plot without title

# %% [markdown]
# # Bar Plot

# %%
ggplot(data=house,aes(x=waterfront,fill=air_cond))+geom_bar()
ggplot(data=house,aes(x=waterfront,fill=air_cond))+geom_bar(position = "fill")
ggplot(data=house,aes(x=waterfront,fill=sewer))+geom_bar(position = "fill")
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # frequency polygon

# %%
ggplot(data=house,aes(x=price))+geom_freqpoly()
ggplot(data=house,aes(x=price))+geom_freqpoly(bins=60)#change bin value for more ditribution
ggplot(data=house,aes(x=price,fill=air_cond))+geom_freqpoly(bins=60)
ggplot(data=house,aes(x=price,col=air_cond))+geom_freqpoly(bins=60)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # box plot

# %%
ggplot(data=house,aes(x=factor(rooms),y=price))+geom_boxplot()
ggplot(data=house,aes(x=factor(rooms),y=price,fill=factor(rooms)))+geom_boxplot()
ggplot(data=house,aes(x=factor(rooms),y=price,fill=sewer))+geom_boxplot()

ggplot(data=house,aes(x=factor(rooms),y=price,fill=air_cond))+geom_boxplot()
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Smooth line

# %%
ggplot(data=house,aes(y=price,x=living_area))+geom_smooth()
ggplot(data=house,aes(y=price,x=living_area))+geom_smooth(se=F)
ggplot(data=house,aes(y=price,x=living_area,col=air_cond))+geom_smooth(se=F)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title
# plot without title

# %% [markdown]
# # statistics in ggplot

# %%
ggplot(data=house,aes(y=price,x=living_area))+geom_point()+geom_smooth(method='lm',se=F)
ggplot(data=house,aes(y=price,x=living_area,col=air_cond))+geom_point()+geom_smooth(
method='lm',se=F)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# `geom_smooth()` using formula 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# # facets

# %%
ggplot(data=house,aes(y=price,x=living_area,col=air_cond))+geom_point()+geom_smooth(method='lm',se=F)+facet_grid(~air_cond)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# # Theme

# %%
obj1<- ggplot(data=house,aes(x=factor(rooms),y=price,fill=factor(rooms)))+geom_boxplot()
obj2<- obj1+labs(title="Price wrt to rooms",x='rooms',fill='rooms')
obj2+theme(panel.background=element_rect(fill='palegreen'))->obj3
obj3+theme(plot.title=element_text(hjust=0.5,face='bold',colour='cadetblue'))->obj4
obj4+scale_y_continuous(labels = scales::dollar_format())
# Out:
# plot without title

# %% [markdown]
# # theme2

# %%
ggplot(data=house,aes(y=price,x=living_area,col=air_cond))+geom_point()+geom_smooth(method='lm',se=F)+facet_grid(~air_cond) -> g1
g1+theme(panel.background = element_rect(fill='palegreen'))-> g2
g2+theme(legend.background = element_rect(fill='lightcyan4'))-> g3
g3+theme(plot.background = element_rect(fill='lightcoral'))
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# # density plot

# %%
x <- rnorm(500)
df <- data.frame(x = x)

ggplot(df, aes(x = x)) +
geom_density(color = 'red', # Curve color
fill = 'red', # Area color
alpha = 0.5) # Area transparency
# Out:
# plot without title

# %%
x=1:10
ggplot(data=x,aes(x=x))+geom_histogram()
# Out:
# Error: `data` must be a data frame, or other object coercible by `fortify()`, not an integer vector.
# Traceback:
#
# 1. ggplot(data = x, aes(x = x))
# 2. ggplot.default(data = x, aes(x = x))
# 3. fortify(data, ...)
# 4. fortify.default(data, ...)
# 5. abort(msg)
# 6. signal_abort(cnd)
